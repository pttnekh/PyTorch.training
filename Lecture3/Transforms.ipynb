# %% [markdown]
# # Transforms
#
# <br>
# 데이터를 모델 입력 형태에 맞게 바꾸거나(전처리), 학습이 잘 되게 변형하는(증강) 단계
#
# 이미지 => 텐서화 by ToTensor
#
# 라벨 => 원핫 인코딩 by Lambda

# %% [markdown]
# 데이터를 변형시켜 텐서로 만들어 훈련에 적합한 형태로 가공한다.

# %% [markdown]
# The FashionMNIST features are in PIL Image format, and the labels are integers. For training, we need the features as normalized tensors, and the labels as one-hot encoded tensors. To make these transformations, we use ToTensor and Lambda.

# %%
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

ds = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(), 
    # Convert PIL images or Numpy's ndarray to (Float)tensors
    # scales the image’s pixel intensity values in the range [0., 1.] -> 원핫 인코딩
    target_transform=Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(0, torch.tensor(y), value=1))
    # target_transform = Lambda(lambda y: torch.nn.functional.one_hot(torch.tensor(y), num_classes=10).float())
)

# %%
target_transform = Lambda(lambda y: torch.zeros(
    10, dtype=torch.float).scatter_(dim=0, index=torch.tensor(y), value=1))

#
